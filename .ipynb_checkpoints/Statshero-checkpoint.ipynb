# %%
# Import all necessary packages
import openai
import runpy
import subprocess
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tabulate import tabulate
from statsmodels.tsa.stattools import adfuller
import cleaning

openai.api_key = "sk-GMn7jAR03BVAGBNPnlqET3BlbkFJCcTI5376Z7IcJCEAoPSgO"
path = "C:/Users/int_shansiming/Desktop/Prediction/Nasdaq.csv"
path2 = "C:/Users/int_shansiming/Desktop/Prediction/data.csv"
path3 = "C:/Users/int_shansiming/Desktop/Prediction/DailyDelhiClimateTest.csv"

# ------------------------------------------
# Set up the parameters for the GPT-3 API
model_text = "text-davinci-002"
model_code = "text-davinci-002"
temperature_1 = 0.1
temperature_2 = 1
max_tokens = 3200

# ------------------------------------------
# Ask for file location
user_input_file = input("Enter the file location:");

# import the data
try:
    user_data = cleaning.clean(user_input_file)
except ValueError:
    user_data = cleaning.clean(user_input_file)

# Then get the column names
col_name = user_data.columns.tolist()

# Enter request
user_request = input("Please enter your request: ")

# Get the desired variables from the input request
from request_matching import parse_user_input, select_variables_and_model

parsed_msg = parse_user_input(user_request)
selected_v = select_variables_and_model(parsed_msg)
selected_type = []
for v in selected_v:
    v_type = user_data[v]
    selected_type.append(v_type)
    
    return selected_type

features_x = input(f"Select your x from {col_name}: ");
features_y = input(f"Select your y from {col_name}: ");
x_type = user_data[features_x].dtype
y_type = user_data[features_y].dtype
prompt = f'''Based on the name and the type of x and y, distinguish what is the best model for prediction
the name of x is {features_x}
the name of y is {features_y}
the type of x is {x_type}
the type of y is {y_type}
print only the name of the best model, no explainations needed
'''
response_text = openai.Completion.create(
    engine=model_text,
    prompt=prompt,
    max_tokens=max_tokens,
    temperature=1,
)
rec_ml = "The recommended model for these features is" + f'''{response_text.choices[0].text.strip()}'''
print(rec_ml)

# ------------------------------------------



print(" ")
print("\033[1m\033[4m\033[36mPlot\033[0m")
print(" ")

prompt = f'''
   Generate Python code to accomplish the following tasks:
1. Import cleaning.py and use the cleaning.clean({user_input_file}), save as 'df'.
2. Import matplotlib.pyplot as plt and create a plot to display the relationship between x = {features_x} and y = {features_y}.
3. make the size of the plot: plt.figure(figsize=(12, 6))
4. Add a title to the graph using the Matplotlib library.
5. Label the axes using appropriate units based on the names of the features.
6. use plt.show() in the end of the code


Please provide the code without any additional comments or notes.
    '''
    # Generate code using the GPT-3 API
response = openai.Completion.create(
    engine=model_code,
    prompt=prompt,
    max_tokens=max_tokens,
    temperature=temperature_1,
)

# Save the generated code to a file
with open("generated_code.py", "w") as f:
    f.write(response.choices[0].text.strip())

# Import the generated code as a module
import generated_code
runpy.run_path("generated_code.py")


# ------------------------------------------
# Using openai api to generate a comprehensive report
print(" ")
print("\033[1m\033[4m\033[36mIntroduction to the variables\033[0m")
print(" ")
prompt_text = f'''
Using the Excel file {user_input_file}, please provide a brief introduction to the following variables: 
{col_name}. 
Please only describe these variables and do not create any new ones. 
'''

response_text = openai.Completion.create(
    engine=model_text,
    prompt=prompt_text,
    max_tokens=max_tokens,
    temperature=temperature_2,
)
print(f'''{response_text.choices[0].text.strip()}''')

# --------------------------
# Generate the descriptive statistics
print(" ")
print("\033[1m\033[4m\033[36mDescriptive statistics\033[0m")
print(" ")
from Descriptive_statistics import des_chart

des_stats = des_chart(user_input_file)
print(tabulate(des_stats, headers='keys', tablefmt='github', showindex=True))

# Write a prompt that can read the descriptive statistics
prompt_des_stats = f'''
Here is a chart of descriptive statistics from the Excel file {user_input_file}:
{des_stats}
Please provide a detailed description and insights of the main characteristics and patterns in this summary chart
In a professional statistician's tongue.
'''

response_text = openai.Completion.create(
    engine=model_text,
    prompt=prompt_des_stats,
    max_tokens=max_tokens,
    temperature=temperature_2,
)
print(f'''{response_text.choices[0].text.strip()}''')

# --------------------------
# Generate the correlation relationship chart
print(" ")
print("\033[1m\033[4m\033[36mCorrelation\033[0m")
print(" ")
from Descriptive_statistics import cor_chart

cor_stats = cor_chart(user_input_file)
print(tabulate(cor_stats, headers='keys', tablefmt='github', showindex=True))

prompt_cor_stats = f'''
Here is a chart of correlation from the Excel file {user_input_file}:
{cor_stats}
Please provide a detailed description and insights of 
the main characteristics and patterns in this correlation chart,
then analyze its insights
In a professional statistician's tongue.
'''

response_text = openai.Completion.create(
    engine=model_text,
    prompt=prompt_cor_stats,
    max_tokens=max_tokens,
    temperature=temperature_2,
)
print(f'''{response_text.choices[0].text.strip()}''')

###

# --------------------------
# --------------------------
# If the data is time series, then whether stationary?
print(" ")
print("\033[1m\033[4m\033[36mTime Series Analysis\033[0m")
print(" ")
from ADF_test import is_stationary
from stationary_plot import sta_plt

# Generate rolling mean and sd plot
sta_plt(user_input_file, features_y)

# Generate if stationary True/False
message_st = is_stationary(user_input_file, features_y)

prompt_cor_stats = f'''
Here is a message about whether the Excel file {user_input_file} is stationary about feature {features_y}:
{message_st}
Please provide a detailed description about stationary,and analyze the meaning of the above message in context
in a neat and professional statistician's tongue.
The output should be in fowllowing format:
A stationary time series data means that:
The above graph indicates that the time series is:
'''
response_text = openai.Completion.create(
    engine=model_text,
    prompt=prompt_cor_stats,
    max_tokens=max_tokens,
    temperature=temperature_2,
)
print(f'''{response_text.choices[0].text.strip()}''')

# Perform ARIMA
from arima import arima_model
arima_model,arima_pred,arima_residuals,arima_summary = arima_model(user_input_file, features_y)
# Use AI to explain the model
prompt_arima = f'''Given an {arima_model} model
please explain the model in detail. Assume that the model has already been fit to a time series dataset.
Please explain the meaning and significance of each of these parameters 
Additionally, please explain how the model was fit to the data, 
and how the predict() and predict_in_sample() methods can be used to forecast future values of the time series.
Finally, please provide any additional insights or observations about the model that you feel would be helpful in understanding its behavior and performance.
'''
response_text = openai.Completion.create(
    engine=model_code,
    prompt=prompt_arima,
    max_tokens=max_tokens,
    temperature=temperature_2,
)
print(f'''{response_text.choices[0].text.strip()}''')

prompt_arima_2 = f'''Given a list of residuals from {arima_residuals}, explain how well an ARIMA model has performed:

The ARIMA model was used to forecast a time series. The model generated a list of residuals by subtracting the predicted values from the actual values. Please analyze the list of residuals and provide a detailed report on how well the ARIMA model has performed. Specifically, please answer the following questions:

1. What is the mean of the residuals?
2. What is the standard deviation of the residuals?
3. Are the residuals normally distributed? 
4. Is there any evidence of autocorrelation in the residuals? 
5. Is there any evidence of heteroscedasticity in the residuals? 
'''
response_text = openai.Completion.create(
    engine=model_text,
    prompt=prompt_arima_2,
    max_tokens=max_tokens,
    temperature=temperature_2,
)
print(f'''{response_text.choices[0].text.strip()}''')

print(arima_summary)
prompt_arima_2 = f'''Please explain the results table for a SARIMAX model generated using the auto_arima function in Python. 
The table is displayed in the following format:
{arima_summary}
Please provide a detailed explanation of the table, including what each column and row represents, 
and the significance of the coefficients and test statistics. 
Based on the value of each coefficients and test statistics, explain how well the model is performing
Additionally, please explain any other relevant information,
such as the model order and how it was determined, and any assumptions that were made in fitting the model.
'''
response_text = openai.Completion.create(
    engine=model_text,
    prompt=prompt_arima_2,
    max_tokens=max_tokens,
    temperature=temperature_2,
)
print(f'''{response_text.choices[0].text.strip()}''')

path = "C:/Users/int_shansiming/Desktop/Prediction/Nasdaq.csv"
path3 = "C:/Users/int_shansiming/Desktop/Prediction/DailyDelhiClimateTest.csv"
# Out:
# Enter the file location:C:/Users/int_shansiming/Desktop/Prediction/DailyDelhiClimateTest.csv
# Select your x from ['Unnamed: 0.1', 'Unnamed: 0', 'date', 'meantemp', 'humidity', 'wind_speed', 'meanpressure']: date
# Select your y from ['Unnamed: 0.1', 'Unnamed: 0', 'date', 'meantemp', 'humidity', 'wind_speed', 'meanpressure']: wind_speed
# The recommended model for these features istime series
#
# Plot
#
# Introduction to the variables
#
# The 'Unnamed: 0.1' and 'Unnamed: 0' variables both represent the index of the row in the dataset. The 'date' variable represents the date of the observation. The 'meantemp' variable represents the mean temperature on that date. The 'humidity' variable represents the mean humidity on that date. The 'wind_speed' variable represents the mean wind speed on that date. The 'meanpressure' variable represents the mean pressure on that date.
#
# Descriptive statistics
#
# |              |       mean |      std |     min |        25% |        50% |       75% |       max |
# |--------------|------------|----------|---------|------------|------------|-----------|-----------|
# | Unnamed: 0.1 |   56.5     | 33.053   |  0      |   28.25    |   56.5     |   84.75   |  113      |
# | Unnamed: 0   |   56.5     | 33.053   |  0      |   28.25    |   56.5     |   84.75   |  113      |
# | meantemp     |   21.7131  |  6.36007 | 11      |   16.4372  |   19.875   |   27.7054 |   34.5    |
# | humidity     |   56.2584  | 19.0681  | 17.75   |   39.625   |   57.75    |   71.9028 |   95.8333 |
# | wind_speed   |    8.14392 |  3.58805 |  1.3875 |    5.56354 |    8.06944 |   10.0687 |   19.3143 |
# | meanpressure | 1004.04    | 89.4747  | 59      | 1007.44    | 1012.74    | 1016.74   | 1022.81   |
# - The first thing to note is that the summary statistics are very similar for both the 'Unnamed: 0.1' and 'Unnamed: 0' columns. This suggests that there is little variation between these two variables.
# - The 'meantemp' column has a mean of 21.71 and a standard deviation of 6.36. This suggests that the majority of temperatures are within 6 degrees of the mean.
# - The 'humidity' column has a mean of 56.26 and a standard deviation of 19.07. This suggests that the majority of humidity levels are within 19 degrees of the mean.
# - The 'wind_speed' column has a mean of 8.14 and a standard deviation of 3.59. This suggests that the majority of wind speeds are within 3.5 degrees of the mean.
# - The 'meanpressure' column has a mean of 1004.04 and a standard deviation of 89.47. This suggests that the majority of pressures are within 89.5 degrees of the mean.
#
# Correlation
#
# |              |   Unnamed: 0.1 |   Unnamed: 0 |   meantemp |   humidity |   wind_speed |   meanpressure |
# |--------------|----------------|--------------|------------|------------|--------------|----------------|
# | Unnamed: 0.1 |       1        |     1        |  0.896585  | -0.913062  |     0.277283 |      0.108501  |
# | Unnamed: 0   |       1        |     1        |  0.896585  | -0.913062  |     0.277283 |      0.108501  |
# | meantemp     |       0.896585 |     0.896585 |  1         | -0.857726  |     0.217743 |      0.0306819 |
# | humidity     |      -0.913062 |    -0.913062 | -0.857726  |  1         |    -0.340507 |     -0.0978688 |
# | wind_speed   |       0.277283 |     0.277283 |  0.217743  | -0.340507  |     1        |      0.130352  |
# | meanpressure |       0.108501 |     0.108501 |  0.0306819 | -0.0978688 |     0.130352 |      1         |
# This correlation chart indicates that there is a moderate positive correlation between mean temperature and wind speed, and a moderate negative correlation between humidity and mean pressure. There is also a weak positive correlation between mean temperature and mean pressure.
#
# Overall, this correlation chart shows that wind speed, mean temperature, and humidity are the most relevant factors in determining mean pressure.
#
# Time Series Analysis
# Stationary time series are important because:
#
# A stationary time series is one in which the statistical properties (mean, variance, autocorrelation, etc.) do not change over time. This is usually caused by the underlying data generating process being stationary.
#
# The above message indicates that the Excel file C:/Users/int_shansiming/Desktop/Prediction/DailyDelhiClimateTest.csv is stationary about feature wind_speed. This means that the mean, variance, and autocorrelation of the wind speed data do not change over time.
#
# Stationary time series are important because they are easier to model and predict than non-stationary time series. This is because stationary time series have constant statistical properties, while non-stationary time series do not. Stationary time series are also easier to understand, because the same statistical properties apply at all times.
# The ARIMA(1,1,1)(0,0,0)[0] model is an autoregressive moving average model with one autoregressive term, one differencing term, and one moving average term. The model also has a constant term and a seasonal component. The model was fit to the data using least squares. The predict() and predict_in_sample() methods can be used to forecast future values of the time series. The constant term is used to model the mean of the time series, the autoregressive term is used to model the autocorrelation of the time series, the differencing term is used to model the stationarity of the time series, and the moving average term is used to model the error.
# 6. Based on your analysis, do you believe that the ARIMA model has performed well? Why or why not?
#
# 1. The mean of the residuals is 0.38.
# 2. The standard deviation of the residuals is 1.52.
# 3. The residuals are not normally distributed.
# 4. There is evidence of autocorrelation in the residuals.
# 5. There is evidence of heteroscedasticity in the residuals.
# 6. Based on the analysis, it is believed that the ARIMA model has not performed well. The main reason is that the residuals are not normally distributed, which indicates that the model is not accurately capturing the underlying data. Additionally, the autocorrelation and heteroscedasticity in the residuals suggest that the model is not stable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  114
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -293.076
# Date:                Wed, 22 Mar 2023   AIC                            592.151
# Time:                        15:50:46   BIC                            600.333
# Sample:                             0   HQIC                           595.471
#                                 - 114
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4355      0.097      4.490      0.000       0.245       0.626
# ma.L1         -0.9658      0.029    -33.050      0.000      -1.023      -0.908
# sigma2        10.3111      1.455      7.086      0.000       7.459      13.163
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 0.53
# Prob(Q):                              0.90   Prob(JB):                         0.77
# Heteroskedasticity (H):               1.36   Skew:                             0.11
# Prob(H) (two-sided):                  0.35   Kurtosis:                         2.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# The first column represents the dependent variable, in this case 'y'. The second column represents the number of observations, which is 114. The third column represents the SARIMAX model. The SARIMAX model has three components - the number of AR terms (1), the number of MA terms (1), and the number of differences (1). The fourth column is the log-likelihood, which is a measure of how well the model is performing. A higher log-likelihood indicates a better fit. The fifth column is the AIC, which stands for the Akaike Information Criterion. The AIC is a measure of how well the model is performing, with a lower AIC indicating a better fit. The sixth column is the BIC, which stands for the Bayesian Information Criterion. The BIC is another measure of how well the model is performing, with a lower BIC indicating a better fit. The seventh column is the sample, which is the period of time over which the data was collected. The eighth column is the covariance type. The ninth column is the coefficient for the AR term, which is 0.4355. The tenth column is the standard error for the AR term, which is 0.097. The eleventh column is the z-statistic for the AR term, which is 4.490. The z-statistic is a measure of how significant the coefficient is. A higher z-statistic indicates a more significant coefficient. The twelfth column is the p-value for the AR term, which is 0.000. The p-value is a measure of how likely it is that the coefficient is not actually equal to zero. A lower p-value indicaes a more likely coefficient. The thirteenth column is the confidence interval for the AR term, which is 0.245 to 0.626. This is the range of values that the coefficient is likely to be, based on the data. The fourteenth column is the coefficient for the MA term, which is -0.9658. The fifteenth column is the standard error for the MA term, which is 0.029. The sixteenth column is the z-statistic for the MA term, which is -33.050. The seventeenth column is the p-value for the MA term, which is 0.000. The eighteenth column is the confidence interval for the MA term, which is -1.023 to -0.908. The nineteenth column is the coefficient for the sigma2 term, which is 10.3111. The twentieth column is the standard error for the sigma2 term, which is 1.455. The twenty-first column is the z-statistic for the sigma2 term, which is 7.086. The twenty-second column is the p-value for the sigma2 term, which is 0.000. The twenty-third column is the confidence interval for the sigma2 term, which is 7.459 to 13.163.
#
# The Ljung-Box test is a test of whether the data are autocorrelated. The Jarque-Bera test is a test of whether the data are normally distributed. The Heteroskedasticity test is a test of whether the data are heteroskedastic. Prob(Q) is the probability that the data are not autocorrelated. Prob(JB) is the probability that the data are not normally distributed. Prob(H) is the probability that the data are not heteroskedastic.
#
# The SARIMAX model is a model that uses both the AR and MA terms. The model order is the number of terms in the model. In this case, the model order is 1. This means that there is one AR term and one MA term. The model order was determined using the auto_arima function. This function chose the model order that gave the best fit, based on the AIC and BIC.
#
# The SARIMAX model is fit using the least squares method. This method minimizes the sum of the squared errors. The SARIMAX model makes the following assumptions:
#
# - The data are linear.
# - The data are stationary.
# - The data are not autocorrelated.
# - The data are normally distributed.
# - The data are homoscedastic.

# %%
# Import all necessary packages
import openai
import runpy
import subprocess
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tabulate import tabulate
from statsmodels.tsa.stattools import adfuller
import cleaning
from cleaning import clean
import importlib

openai.api_key = "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"
path = "C:/Users/int_shansiming/Desktop/Prediction/Nasdaq.csv"
path2 = "C:/Users/int_shansiming/Desktop/Prediction/data.csv"
path3 = "C:/Users/int_shansiming/Desktop/Prediction/DailyDelhiClimateTest.csv"

# ------------------------------------------
# Set up the parameters for the GPT-3 API
model_text = "text-davinci-002"
model_code = "text-davinci-002"
temperature_1 = 0.1
temperature_2 = 1
max_tokens = 3200

# ------------------------------------------
# Ask for file location
user_input_file = input("Enter the file location:");

# import the data
try:
    user_data = cleaning.clean(user_input_file)
except ValueError:
    user_data = cleaning.clean(user_input_file)

# Then get the column names
col_name = user_data.columns.tolist()

from request_matching import parse_user_input, select_variables_and_model

while True:
    # Enter request
    user_request = input("Please enter your request: ")

    # Get the desired variables from the input request
    parsed_msg = parse_user_input(user_input_file,user_request)
    # selected_v = select_variables_and_model(user_input_file, user_request)
    selected_v = []
    for v in col_name:
        if v in parsed_msg:
            selected_v.append(v)

    # Check if the selected_v set has more than one element
    if len(selected_v) > 1:
        break
    else:
        print("Please provide a request with at least two variables.")
print(col_name)
selected_type = []
for v in selected_v:
    v_type = user_data[v].dtype
    selected_type.append(v_type)

features_y = input(f"Select your y from {selected_v}: ");
y_index = selected_v.index(features_y)
selected_v.pop(y_index)
y_type = selected_type[y_index]
selected_type.pop(y_index)

success = False
attempts = 0
while not succuss and attempts <1:
    try:
        prompt = f'''Based on the name and the type of x and y, and the request {parsed_msg}
        ,distinguish what is the best statistical model for user's request
        the name of x is {selected_v}
        the name of y is {features_y}
        the type of x is {selected_type} accordingly
        the type of y is {y_type}
        choose one suitable model based on bias-variance trade-off
        print only the name of one suitable modelchoose the model based on bias-variance trade-off, no explainations needed
        '''
        response_text = openai.Completion.create(
            engine=model_text,
            prompt=prompt,
            max_tokens=max_tokens,
            temperature=0.7,
        )
        rec_ml = "The recommended model for these features is " + f'''{response_text.choices[0].text.strip()}'''
        prompt = f'''Write Python code to:
1. Import the necessary packages, including the custom cleaning.py module.
2. Load the dataset using the cleaning.clean function, providing the user's input file {user_input_file} as an argument, and save it as 'df'.
3. Split the dataset into training and testing sets using the dependent variable y represented by {features_y} and the independent variables x represented by {selected_v}.
4. Fit a model using the {rec_ml} method on the training set.
5. Generate predictions using the fitted model on the testing set.
6. Create am appropriate plot of the original data and the predictions using the 'matplotlib.pyplot' library, set the figsize by plt.figure(figsize=(12, 6)).
7. Add a title to the graph using the Matplotlib library.
8. Create an error plot showing the difference between the predictions and testing y values.
9. Add a semicolon at the end of the line that calls plt.show().
10. Save the summary of the model to a variable named 'summary'.
11. Exclude any comments or notes from the code, generate code only.
12. Follow the above instructions step by step, and do not miss any instructions.
13. This should generate code without the step numbers.
        '''

        # Generate code using the GPT-3 API
        response = openai.Completion.create(
            engine=model_code,
            prompt=prompt,
            max_tokens=max_tokens,
            temperature=temperature_1,
        )

        # Save the generated code to a file
        with open("gen_ml_code.py", "w") as f:
            f.write(response.choices[0].text.strip())

        path_to_script = "gen_ml_code.py"
        graph_gen = runpy.run_path(path_to_script)
        success = True
    except Exception as e:
        print(f"Error: {e}")
        attempts += 1


# analyze the relationship between humidity mean teamperature and wind speed, so that i can predict humidity
# C:/Users/int_shansiming/Desktop/Prediction/DailyDelhiClimateTest.csv
# Out:
# Enter the file location:C:/Users/int_shansiming/Desktop/Prediction/DailyDelhiClimateTest.csv
